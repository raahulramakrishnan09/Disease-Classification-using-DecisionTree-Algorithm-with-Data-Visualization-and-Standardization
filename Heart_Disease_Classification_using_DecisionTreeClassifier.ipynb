# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/heart.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
df.tail()
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0

# %%
df.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# min       0.000000     0.000000    71.000000     0.000000     0.000000
# 25%       0.000000     0.000000   132.000000     0.000000     0.000000
# 50%       0.000000     1.000000   152.000000     0.000000     0.800000
# 75%       0.000000     1.000000   166.000000     1.000000     1.800000
# max       1.000000     2.000000   202.000000     1.000000     6.200000
#
#              slope           ca         thal       target
# count  1025.000000  1025.000000  1025.000000  1025.000000
# mean      1.385366     0.754146     2.323902     0.513171
# std       0.617755     1.030798     0.620660     0.500070
# min       0.000000     0.000000     0.000000     0.000000
# 25%       1.000000     0.000000     2.000000     0.000000
# 50%       1.000000     0.000000     2.000000     1.000000
# 75%       2.000000     1.000000     3.000000     1.000000
# max       2.000000     4.000000     3.000000     1.000000

# %%
df.shape
# Out:
# (1025, 14)

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
a=df['chol']
a
b=df['thal']
b
# Out:
# 0       3
# 1       3
# 2       3
# 3       3
# 4       2
#        ..
# 1020    2
# 1021    3
# 1022    2
# 1023    2
# 1024    3
# Name: thal, Length: 1025, dtype: int64

# %%
plt.plot(a)

# %%
plt.scatter(a,b)

# %%
plt.bar(b,height=30)
# Out:
# <BarContainer object of 1025 artists>

# %%
plt.hist(a)
# Out:
# (array([ 42., 247., 359., 231., 120.,  10.,  13.,   0.,   0.,   3.]),
#  array([126. , 169.8, 213.6, 257.4, 301.2, 345. , 388.8, 432.6, 476.4,
#         520.2, 564. ]),
#  <BarContainer object of 10 artists>)

# %%
c=df['sex']
plt.pie(c)
# Out:
# ([<matplotlib.patches.Wedge at 0x7a8e568f9ea0>,
#   <matplotlib.patches.Wedge at 0x7a8e568f8f70>,
#   <matplotlib.patches.Wedge at 0x7a8e568fa770>,
#   <matplotlib.patches.Wedge at 0x7a8e568fabf0>,
#   <matplotlib.patches.Wedge at 0x7a8e568fb070>,
#   <matplotlib.patches.Wedge at 0x7a8e568fb4f0>,
#   <matplotlib.patches.Wedge at 0x7a8e568fb970>,
#   <matplotlib.patches.Wedge at 0x7a8e568fbdf0>,
#   <matplotlib.patches.Wedge at 0x7a8e569302b0>,
#   <matplotlib.patches.Wedge at 0x7a8e56930730>,
#   <matplotlib.patches.Wedge at 0x7a8e568f9e70>,
#   <matplotlib.patches.Wedge at 0x7a8e56931000>,
#   <matplotlib.patches.Wedge at 0x7a8e56a5a740>,
#   <matplotlib.patches.Wedge at 0x7a8e569315a0>,
#   <matplotlib.patches.Wedge at 0x7a8e56931a20>,
#   <matplotlib.patches.Wedge at 0x7a8e56931ea0>,
#   <matplotlib.patches.Wedge at 0x7a8e56932320>,
#   <matplotlib.patches.Wedge at 0x7a8e569327a0>,
#   <matplotlib.patches.Wedge at 0x7a8e56932c20>,
#   <matplotlib.patches.Wedge at 0x7a8e569330a0>,
#   <matplotlib.patches.Wedge at 0x7a8e56933520>,
#   <matplotlib.patches.Wedge at 0x7a8e569339a0>,
#   <matplotlib.patches.Wedge at 0x7a8e56933e20>,
#   <matplotlib.patches.Wedge at 0x7a8e5696c2e0>,
#   <matplotlib.patches.Wedge at 0x7a8e5696c760>,
#   <matplotlib.patches.Wedge at 0x7a8e5696cbe0>,
#   <matplotlib.patches.Wedge at 0x7a8e5696d060>,
#   <matplotlib.patches.Wedge at 0x7a8e5696d4e0>,
#   <matplotlib.patches.Wedge at 0x7a8e5696d960>,
#   <matplotlib.patches.Wedge at 0x7a8e5696dde0>,
#   <matplotlib.patches.Wedge at 0x7a8e5696e260>,
#   <matplotlib.patches.Wedge at 0x7a8e5696e6e0>,
#   <matplotlib.patches.Wedge at 0x7a8e5696eb60>,
#   <matplotlib.patches.Wedge at 0x7a8e5696efe0>,
#   <matplotlib.patches.Wedge at 0x7a8e5696f460>,
#   <matplotlib.patches.Wedge at 0x7a8e5696f8e0>,
#   <matplotlib.patches.Wedge at 0x7a8e5696fd60>,
#   <matplotlib.patches.Wedge at 0x7a8e567a4220>,
#   <matplotlib.patches.Wedge at 0x7a8e567a46a0>,
#   <matplotlib.patches.Wedge at 0x7a8e567a4b20>,
#   <matplotlib.patches.Wedge at 0x7a8e567a4fa0>,
#   <matplotlib.patches.Wedge at 0x7a8e567a5420>,
#   <matplotlib.patches.Wedge at 0x7a8e567a58a0>,
#   <matplotlib.patches.Wedge at 0x7a8e567a5d20>,
#   <matplotlib.patches.Wedge at 0x7a8e567a61a0>,
#   <matplotlib.patches.Wedge at 0x7a8e567a6620>,
#   <matplotlib.patches.Wedge at 0x7a8e567a6aa0>,
#   <matplotlib.patches.Wedge at 0x7a8e567a6f20>,
#   <matplotlib.patches.Wedge at 0x7a8e567a73a0>,
#   <matplotlib.patches.Wedge at 0x7a8e567a7820>,
#   <matplotlib.patches.Wedge at 0x7a8e567a7ca0>,
#   <matplotlib.patches.Wedge at 0x7a8e567d8160>,
#   <matplotlib.patches.Wedge at 0x7a8e567d85e0>,
#   <matplotlib.patches.Wedge at 0x7a8e567d8a60>,
#   <matplotlib.patches.Wedge at 0x7a8e567d8ee0>,
#   <matplotlib.patches.Wedge at 0x7a8e567d9360>,
#   <matplotlib.patches.Wedge at 0x7a8e567d97e0>,
#   <matplotlib.patches.Wedge at 0x7a8e567d9c60>,
#   <matplotlib.patches.Wedge at 0x7a8e567da0e0>,
#   <matplotlib.patches.Wedge at 0x7a8e567da560>,
#   <matplotlib.patches.Wedge at 0x7a8e567da9e0>,
#   <matplotlib.patches.Wedge at 0x7a8e567dae60>,
#   <matplotlib.patches.Wedge at 0x7a8e567db2e0>,
#   <matplotlib.patches.Wedge at 0x7a8e567db760>,
#   <matplotlib.patches.Wedge at 0x7a8e567dbbe0>,
#   <matplotlib.patches.Wedge at 0x7a8e568100a0>,
#   <matplotlib.patches.Wedge at 0x7a8e56810520>,
#   <matplotlib.patches.Wedge at 0x7a8e568109a0>,
#   <matplotlib.patches.Wedge at 0x7a8e56810e20>,
#   <matplotlib.patches.Wedge at 0x7a8e568112a0>,
#   <matplotlib.patches.Wedge at 0x7a8e56811720>,
#   <matplotlib.patches.Wedge at 0x7a8e56811ba0>,
#   <matplotlib.patches.Wedge at 0x7a8e56812020>,
#   <matplotlib.patches.Wedge at 0x7a8e568124a0>,
#   <matplotlib.patches.Wedge at 0x7a8e56812920>,
#   <matplotlib.patches.Wedge at 0x7a8e56812da0>,
#   <matplotlib.patches.Wedge at 0x7a8e56813220>,
#   <matplotlib.patches.Wedge at 0x7a8e568136a0>,
#   <matplotlib.patches.Wedge at 0x7a8e56813b20>,
#   <matplotlib.patches.Wedge at 0x7a8e56813fa0>,
#   <matplotlib.patches.Wedge at 0x7a8e56848460>,
#   <matplotlib.patches.Wedge at 0x7a8e568488e0>,
#   <matplotlib.patches.Wedge at 0x7a8e56848d60>,
#   <matplotlib.patches.Wedge at 0x7a8e568491e0>,
#   <matplotlib.patches.Wedge at 0x7a8e56849660>,
#   <matplotlib.patches.Wedge at 0x7a8e56849ae0>,
#   <matplotlib.patches.Wedge at 0x7a8e56849f60>,
#   <matplotlib.patches.Wedge at 0x7a8e5684a3e0>,
#   <matplotlib.patches.Wedge at 0x7a8e5684a860>,
#   <matplotlib.patches.Wedge at 0x7a8e5684ace0>,
#   <matplotlib.patches.Wedge at 0x7a8e5684b160>,
#   <matplotlib.patches.Wedge at 0x7a8e5684b5e0>,
#   <matplotlib.patches.Wedge at 0x7a8e5684ba60>,
#   <matplotlib.patches.Wedge at 0x7a8e5684bee0>,
#   <matplotlib.patches.Wedge at 0x7a8e568803a0>,
#   <matplotlib.patches.Wedge at 0x7a8e56880820>,
#   <matplotlib.patches.Wedge at 0x7a8e56880ca0>,
#   <matplotlib.patches.Wedge at 0x7a8e56881120>,
#   <matplotlib.patches.Wedge at 0x7a8e568815a0>,
#   <matplotlib.patches.Wedge at 0x7a8e56881a20>,
#   <matplotlib.patches.Wedge at 0x7a8e56881ea0>,
#   <matplotlib.patches.Wedge at 0x7a8e56882320>,
#   <matplotlib.patches.Wedge at 0x7a8e568827a0>,
#   <matplotlib.patches.Wedge at 0x7a8e56882c20>,
#   <matplotlib.patches.Wedge at 0x7a8e568830a0>,
#   <matplotlib.patches.Wedge at 0x7a8e56883520>,
#   <matplotlib.patches.Wedge at 0x7a8e568839a0>,
#   <matplotlib.patches.Wedge at 0x7a8e56883e20>,
#   <matplotlib.patches.Wedge at 0x7a8e566c02e0>,
#   <matplotlib.patches.Wedge at 0x7a8e566c0760>,
#   <matplotlib.patches.Wedge at 0x7a8e566c0be0>,
#   <matplotlib.patches.Wedge at 0x7a8e566c1060>,
#   <matplotlib.patches.Wedge at 0x7a8e566c14e0>,
#   <matplotlib.patches.Wedge at 0x7a8e566c1960>,
#   <matplotlib.patches.Wedge at 0x7a8e566c1de0>,
#   <matplotlib.patches.Wedge at 0x7a8e566c2260>,
#   <matplotlib.patches.Wedge at 0x7a8e566c26e0>,
#   <matplotlib.patches.Wedge at 0x7a8e566c2b60>,
#   <matplotlib.patches.Wedge at 0x7a8e566c2fe0>,
#   <matplotlib.patches.Wedge at 0x7a8e566c3460>,
#   <matplotlib.patches.Wedge at 0x7a8e566c38e0>,
#   <matplotlib.patches.Wedge at 0x7a8e566c3d60>,
#   <matplotlib.patches.Wedge at 0x7a8e566f8220>,
#   <matplotlib.patches.Wedge at 0x7a8e566f86a0>,
#   <matplotlib.patches.Wedge at 0x7a8e566f8b20>,
#   <matplotlib.patches.Wedge at 0x7a8e566f8eb0>,
#   <matplotlib.patches.Wedge at 0x7a8e566f93f0>,
#   <matplotlib.patches.Wedge at 0x7a8e566f9870>,
#   <matplotlib.patches.Wedge at 0x7a8e566f9cf0>,
#   <matplotlib.patches.Wedge at 0x7a8e566fa170>,
#   <matplotlib.patches.Wedge at 0x7a8e566fa5f0>,
#   <matplotlib.patches.Wedge at 0x7a8e566faa70>,
#   <matplotlib.patches.Wedge at 0x7a8e566faef0>,
#   <matplotlib.patches.Wedge at 0x7a8e566fb370>,
#   <matplotlib.patches.Wedge at 0x7a8e566fb7f0>,
#   <matplotlib.patches.Wedge at 0x7a8e566fbc70>,
#   <matplotlib.patches.Wedge at 0x7a8e56738130>,
#   <matplotlib.patches.Wedge at 0x7a8e567385b0>,
#   <matplotlib.patches.Wedge at 0x7a8e56738a30>,
#   <matplotlib.patches.Wedge at 0x7a8e56738eb0>,
#   <matplotlib.patches.Wedge at 0x7a8e56739330>,
#   <matplotlib.patches.Wedge at 0x7a8e567397b0>,
#   <matplotlib.patches.Wedge at 0x7a8e56739c30>,
#   <matplotlib.patches.Wedge at 0x7a8e5673a0b0>,
#   <matplotlib.patches.Wedge at 0x7a8e5673a530>,
#   <matplotlib.patches.Wedge at 0x7a8e5673a9b0>,
#   <matplotlib.patches.Wedge at 0x7a8e5673ae30>,
#   <matplotlib.patches.Wedge at 0x7a8e5673b2b0>,
#   <matplotlib.patches.Wedge at 0x7a8e5673b730>,
#   <matplotlib.patches.Wedge at 0x7a8e5673bbb0>,
#   <matplotlib.patches.Wedge at 0x7a8e56774070>,
#   <matplotlib.patches.Wedge at 0x7a8e567744f0>,
#   <matplotlib.patches.Wedge at 0x7a8e56774970>,
#   <matplotlib.patches.Wedge at 0x7a8e56774df0>,
#   <matplotlib.patches.Wedge at 0x7a8e56775270>,
#   <matplotlib.patches.Wedge at 0x7a8e567756f0>,
#   <matplotlib.patches.Wedge at 0x7a8e56775b70>,
#   <matplotlib.patches.Wedge at 0x7a8e56775ff0>,
#   <matplotlib.patches.Wedge at 0x7a8e56776470>,
#   <matplotlib.patches.Wedge at 0x7a8e567768f0>,
#   <matplotlib.patches.Wedge at 0x7a8e56776d70>,
#   <matplotlib.patches.Wedge at 0x7a8e567771f0>,
#   <matplotlib.patches.Wedge at 0x7a8e56777670>,
#   <matplotlib.patches.Wedge at 0x7a8e56777af0>,
#   <matplotlib.patches.Wedge at 0x7a8e56777f70>,
#   <matplotlib.patches.Wedge at 0x7a8e565a8430>,
#   <matplotlib.patches.Wedge at 0x7a8e565a88b0>,
#   <matplotlib.patches.Wedge at 0x7a8e565a8d60>,
#   <matplotlib.patches.Wedge at 0x7a8e565a91e0>,
#   <matplotlib.patches.Wedge at 0x7a8e565a9660>,
#   <matplotlib.patches.Wedge at 0x7a8e565a9ae0>,
#   <matplotlib.patches.Wedge at 0x7a8e565a9f60>,
#   <matplotlib.patches.Wedge at 0x7a8e565aa3e0>,
#   <matplotlib.patches.Wedge at 0x7a8e565aa860>,
#   <matplotlib.patches.Wedge at 0x7a8e565aace0>,
#   <matplotlib.patches.Wedge at 0x7a8e565ab160>,
#   <matplotlib.patches.Wedge at 0x7a8e565ab5e0>,
#   <matplotlib.patches.Wedge at 0x7a8e565aba60>,
#   <matplotlib.patches.Wedge at 0x7a8e565abee0>,
#   <matplotlib.patches.Wedge at 0x7a8e565e83a0>,
#   <matplotlib.patches.Wedge at 0x7a8e565e8820>,
#   <matplotlib.patches.Wedge at 0x7a8e565e8ca0>,
#   <matplotlib.patches.Wedge at 0x7a8e565e9120>,
#   <matplotlib.patches.Wedge at 0x7a8e565e95a0>,
#   <matplotlib.patches.Wedge at 0x7a8e565e9a20>,
#   <matplotlib.patches.Wedge at 0x7a8e565e9ea0>,
#   <matplotlib.patches.Wedge at 0x7a8e565ea320>,
#   <matplotlib.patches.Wedge at 0x7a8e565ea7a0>,
#   <matplotlib.patches.Wedge at 0x7a8e565eac20>,
#   <matplotlib.patches.Wedge at 0x7a8e565eb0a0>,
#   <matplotlib.patches.Wedge at 0x7a8e565eb520>,
#   <matplotlib.patches.Wedge at 0x7a8e565eb9a0>,
#   <matplotlib.patches.Wedge at 0x7a8e565ebe20>,
#   <matplotlib.patches.Wedge at 0x7a8e566202e0>,
#   <matplotlib.patches.Wedge at 0x7a8e56620760>,
#   <matplotlib.patches.Wedge at 0x7a8e56620be0>,
#   <matplotlib.patches.Wedge at 0x7a8e56621060>,
#   <matplotlib.patches.Wedge at 0x7a8e566214e0>,
#   <matplotlib.patches.Wedge at 0x7a8e56621960>,
#   <matplotlib.patches.Wedge at 0x7a8e56621de0>,
#   <matplotlib.patches.Wedge at 0x7a8e56622260>,
#   <matplotlib.patches.Wedge at 0x7a8e566226e0>,
#   <matplotlib.patches.Wedge at 0x7a8e56622b60>,
#   <matplotlib.patches.Wedge at 0x7a8e56622fe0>,
#   <matplotlib.patches.Wedge at 0x7a8e56623460>,
#   <matplotlib.patches.Wedge at 0x7a8e566238e0>,
#   <matplotlib.patches.Wedge at 0x7a8e56623d60>,
#   <matplotlib.patches.Wedge at 0x7a8e5665c220>,
#   <matplotlib.patches.Wedge at 0x7a8e5665c6a0>,
#   <matplotlib.patches.Wedge at 0x7a8e5665cb20>,
#   <matplotlib.patches.Wedge at 0x7a8e5665cfa0>,
#   <matplotlib.patches.Wedge at 0x7a8e5665d420>,
#   <matplotlib.patches.Wedge at 0x7a8e5665d8a0>,
#   <matplotlib.patches.Wedge at 0x7a8e5665dd20>,
#   <matplotlib.patches.Wedge at 0x7a8e5665e1a0>,
#   <matplotlib.patches.Wedge at 0x7a8e5665e620>,
#   <matplotlib.patches.Wedge at 0x7a8e5665eaa0>,
#   <matplotlib.patches.Wedge at 0x7a8e5665ef20>,
#   <matplotlib.patches.Wedge at 0x7a8e5665f3a0>,
#   <matplotlib.patches.Wedge at 0x7a8e5665f820>,
#   <matplotlib.patches.Wedge at 0x7a8e5665fca0>,
#   <matplotlib.patches.Wedge at 0x7a8e56494160>,
#   <matplotlib.patches.Wedge at 0x7a8e564945e0>,
#   <matplotlib.patches.Wedge at 0x7a8e56494a60>,
#   <matplotlib.patches.Wedge at 0x7a8e56494ee0>,
#   <matplotlib.patches.Wedge at 0x7a8e56495360>,
#   <matplotlib.patches.Wedge at 0x7a8e564957e0>,
#   <matplotlib.patches.Wedge at 0x7a8e56495c60>,
#   <matplotlib.patches.Wedge at 0x7a8e564960e0>,
#   <matplotlib.patches.Wedge at 0x7a8e56496560>,
#   <matplotlib.patches.Wedge at 0x7a8e564969e0>,
#   <matplotlib.patches.Wedge at 0x7a8e56496e60>,
#   <matplotlib.patches.Wedge at 0x7a8e564972e0>,
#   <matplotlib.patches.Wedge at 0x7a8e56497760>,
#   <matplotlib.patches.Wedge at 0x7a8e56497be0>,
#   <matplotlib.patches.Wedge at 0x7a8e564d00a0>,
#   <matplotlib.patches.Wedge at 0x7a8e564d0520>,
#   <matplotlib.patches.Wedge at 0x7a8e564d09a0>,
#   <matplotlib.patches.Wedge at 0x7a8e564d0e20>,
#   <matplotlib.patches.Wedge at 0x7a8e564d12a0>,
#   <matplotlib.patches.Wedge at 0x7a8e564d1720>,
#   <matplotlib.patches.Wedge at 0x7a8e564d1ba0>,
#   <matplotlib.patches.Wedge at 0x7a8e564d2020>,
#   <matplotlib.patches.Wedge at 0x7a8e564d24a0>,
#   <matplotlib.patches.Wedge at 0x7a8e564d2920>,
#   <matplotlib.patches.Wedge at 0x7a8e564d2da0>,
#   <matplotlib.patches.Wedge at 0x7a8e564d3220>,
#   <matplotlib.patches.Wedge at 0x7a8e564d36a0>,
#   <matplotlib.patches.Wedge at 0x7a8e564d3b20>,
#   <matplotlib.patches.Wedge at 0x7a8e564d3fa0>,
#   <matplotlib.patches.Wedge at 0x7a8e56508460>,
#   <matplotlib.patches.Wedge at 0x7a8e565088e0>,
#   <matplotlib.patches.Wedge at 0x7a8e56508d60>,
#   <matplotlib.patches.Wedge at 0x7a8e565091e0>,
#   <matplotlib.patches.Wedge at 0x7a8e56509660>,
#   <matplotlib.patches.Wedge at 0x7a8e56509ae0>,
#   <matplotlib.patches.Wedge at 0x7a8e56509f60>,
#   <matplotlib.patches.Wedge at 0x7a8e5650a3e0>,
#   <matplotlib.patches.Wedge at 0x7a8e5650a860>,
#   <matplotlib.patches.Wedge at 0x7a8e5650ace0>,
#   <matplotlib.patches.Wedge at 0x7a8e5650b160>,
#   <matplotlib.patches.Wedge at 0x7a8e5650b5e0>,
#   <matplotlib.patches.Wedge at 0x7a8e5650ba60>,
#   <matplotlib.patches.Wedge at 0x7a8e5650bee0>,
#   <matplotlib.patches.Wedge at 0x7a8e565403a0>,
#   <matplotlib.patches.Wedge at 0x7a8e56540820>,
#   <matplotlib.patches.Wedge at 0x7a8e56540ca0>,
#   <matplotlib.patches.Wedge at 0x7a8e56541120>,
#   <matplotlib.patches.Wedge at 0x7a8e565415a0>,
#   <matplotlib.patches.Wedge at 0x7a8e56541a20>,
#   <matplotlib.patches.Wedge at 0x7a8e56541ea0>,
#   <matplotlib.patches.Wedge at 0x7a8e56542320>,
#   <matplotlib.patches.Wedge at 0x7a8e565427a0>,
#   <matplotlib.patches.Wedge at 0x7a8e56542c20>,
#   <matplotlib.patches.Wedge at 0x7a8e565430a0>,
#   <matplotlib.patches.Wedge at 0x7a8e56543520>,
#   <matplotlib.patches.Wedge at 0x7a8e565439a0>,
#   <matplotlib.patches.Wedge at 0x7a8e56543e20>,
#   <matplotlib.patches.Wedge at 0x7a8e5657c2e0>,
#   <matplotlib.patches.Wedge at 0x7a8e5657c760>,
#   <matplotlib.patches.Wedge at 0x7a8e5657cbe0>,
#   <matplotlib.patches.Wedge at 0x7a8e5657d060>,
#   <matplotlib.patches.Wedge at 0x7a8e5657d4e0>,
#   <matplotlib.patches.Wedge at 0x7a8e5657d960>,
#   <matplotlib.patches.Wedge at 0x7a8e5657dde0>,
#   <matplotlib.patches.Wedge at 0x7a8e5657e260>,
#   <matplotlib.patches.Wedge at 0x7a8e5657e6e0>,
#   <matplotlib.patches.Wedge at 0x7a8e5657eb60>,
#   <matplotlib.patches.Wedge at 0x7a8e5657efe0>,
#   <matplotlib.patches.Wedge at 0x7a8e5657f460>,
#   <matplotlib.patches.Wedge at 0x7a8e5657f8e0>,
#   <matplotlib.patches.Wedge at 0x7a8e5657fd60>,
#   <matplotlib.patches.Wedge at 0x7a8e563c0220>,
#   <matplotlib.patches.Wedge at 0x7a8e563c06a0>,
#   <matplotlib.patches.Wedge at 0x7a8e563c0b20>,
#   <matplotlib.patches.Wedge at 0x7a8e563c0fa0>,
#   <matplotlib.patches.Wedge at 0x7a8e563c1420>,
#   <matplotlib.patches.Wedge at 0x7a8e563c18a0>,
#   <matplotlib.patches.Wedge at 0x7a8e563c1d20>,
#   <matplotlib.patches.Wedge at 0x7a8e563c21a0>,
#   <matplotlib.patches.Wedge at 0x7a8e563c2620>,
#   <matplotlib.patches.Wedge at 0x7a8e563c2aa0>,
#   <matplotlib.patches.Wedge at 0x7a8e563c2f20>,
#   <matplotlib.patches.Wedge at 0x7a8e563c33a0>,
#   <matplotlib.patches.Wedge at 0x7a8e563c3820>,
#   <matplotlib.patches.Wedge at 0x7a8e563c3ca0>,
#   <matplotlib.patches.Wedge at 0x7a8e563f4160>,
#   <matplotlib.patches.Wedge at 0x7a8e563f45e0>,
#   <matplotlib.patches.Wedge at 0x7a8e563f4a60>,
#   <matplotlib.patches.Wedge at 0x7a8e563f4ee0>,
#   <matplotlib.patches.Wedge at 0x7a8e563f5360>,
#   <matplotlib.patches.Wedge at 0x7a8e563f57e0>,
#   <matplotlib.patches.Wedge at 0x7a8e563f5c60>,
#   <matplotlib.patches.Wedge at 0x7a8e563f60e0>,
#   <matplotlib.patches.Wedge at 0x7a8e563f6560>,
#   <matplotlib.patches.Wedge at 0x7a8e563f69e0>,
#   <matplotlib.patches.Wedge at 0x7a8e563f6e60>,
#   <matplotlib.patches.Wedge at 0x7a8e563f72e0>,
#   <matplotlib.patches.Wedge at 0x7a8e563f7760>,
#   <matplotlib.patches.Wedge at 0x7a8e563f7be0>,
#   <matplotlib.patches.Wedge at 0x7a8e564300a0>,
#   <matplotlib.patches.Wedge at 0x7a8e56430520>,
#   <matplotlib.patches.Wedge at 0x7a8e564309a0>,
#   <matplotlib.patches.Wedge at 0x7a8e56430e20>,
#   <matplotlib.patches.Wedge at 0x7a8e564312a0>,
#   <matplotlib.patches.Wedge at 0x7a8e56431720>,
#   <matplotlib.patches.Wedge at 0x7a8e56431ba0>,
#   <matplotlib.patches.Wedge at 0x7a8e56432020>,
#   <matplotlib.patches.Wedge at 0x7a8e564324a0>,
#   <matplotlib.patches.Wedge at 0x7a8e56432920>,
#   <matplotlib.patches.Wedge at 0x7a8e56432da0>,
#   <matplotlib.patches.Wedge at 0x7a8e56433220>,
#   <matplotlib.patches.Wedge at 0x7a8e564336a0>,
#   <matplotlib.patches.Wedge at 0x7a8e56433b20>,
#   <matplotlib.patches.Wedge at 0x7a8e56433fa0>,
#   <matplotlib.patches.Wedge at 0x7a8e56468460>,
#   <matplotlib.patches.Wedge at 0x7a8e564688e0>,
#   <matplotlib.patches.Wedge at 0x7a8e56468d60>,
#   <matplotlib.patches.Wedge at 0x7a8e564691e0>,
#   <matplotlib.patches.Wedge at 0x7a8e56469660>,
#   <matplotlib.patches.Wedge at 0x7a8e56469ae0>,
#   <matplotlib.patches.Wedge at 0x7a8e56469f60>,
#   <matplotlib.patches.Wedge at 0x7a8e5646a3e0>,
#   <matplotlib.patches.Wedge at 0x7a8e5646a860>,
#   <matplotlib.patches.Wedge at 0x7a8e5646ace0>,
#   <matplotlib.patches.Wedge at 0x7a8e5646b160>,
#   <matplotlib.patches.Wedge at 0x7a8e5646b5e0>,
#   <matplotlib.patches.Wedge at 0x7a8e5646ba60>,
#   <matplotlib.patches.Wedge at 0x7a8e5646bee0>,
#   <matplotlib.patches.Wedge at 0x7a8e562a83a0>,
#   <matplotlib.patches.Wedge at 0x7a8e562a8820>,
#   <matplotlib.patches.Wedge at 0x7a8e562a8ca0>,
#   <matplotlib.patches.Wedge at 0x7a8e562a9120>,
#   <matplotlib.patches.Wedge at 0x7a8e562a95a0>,
#   <matplotlib.patches.Wedge at 0x7a8e562a9a20>,
#   <matplotlib.patches.Wedge at 0x7a8e562a9ea0>,
#   <matplotlib.patches.Wedge at 0x7a8e562aa320>,
#   <matplotlib.patches.Wedge at 0x7a8e562aa7a0>,
#   <matplotlib.patches.Wedge at 0x7a8e562aac20>,
#   <matplotlib.patches.Wedge at 0x7a8e562ab0a0>,
#   <matplotlib.patches.Wedge at 0x7a8e562ab520>,
#   <matplotlib.patches.Wedge at 0x7a8e562ab9a0>,
#   <matplotlib.patches.Wedge at 0x7a8e562abe20>,
#   <matplotlib.patches.Wedge at 0x7a8e562dc2e0>,
#   <matplotlib.patches.Wedge at 0x7a8e562dc760>,
#   <matplotlib.patches.Wedge at 0x7a8e562dcbe0>,
#   <matplotlib.patches.Wedge at 0x7a8e562dd060>,
#   <matplotlib.patches.Wedge at 0x7a8e562dd4e0>,
#   <matplotlib.patches.Wedge at 0x7a8e562dd960>,
#   <matplotlib.patches.Wedge at 0x7a8e562ddde0>,
#   <matplotlib.patches.Wedge at 0x7a8e562de260>,
#   <matplotlib.patches.Wedge at 0x7a8e562de6e0>,
#   <matplotlib.patches.Wedge at 0x7a8e562deb60>,
#   <matplotlib.patches.Wedge at 0x7a8e562defe0>,
#   <matplotlib.patches.Wedge at 0x7a8e562df460>,
#   <matplotlib.patches.Wedge at 0x7a8e562df8e0>,
#   <matplotlib.patches.Wedge at 0x7a8e562dfd60>,
#   <matplotlib.patches.Wedge at 0x7a8e56318220>,
#   <matplotlib.patches.Wedge at 0x7a8e563186a0>,
#   <matplotlib.patches.Wedge at 0x7a8e56318b20>,
#   <matplotlib.patches.Wedge at 0x7a8e56318fa0>,
#   <matplotlib.patches.Wedge at 0x7a8e56319420>,
#   <matplotlib.patches.Wedge at 0x7a8e563198a0>,
#   <matplotlib.patches.Wedge at 0x7a8e56319d20>,
#   <matplotlib.patches.Wedge at 0x7a8e5631a1a0>,
#   <matplotlib.patches.Wedge at 0x7a8e5631a620>,
#   <matplotlib.patches.Wedge at 0x7a8e5631aaa0>,
#   <matplotlib.patches.Wedge at 0x7a8e5631af20>,
#   <matplotlib.patches.Wedge at 0x7a8e5631b3a0>,
#   <matplotlib.patches.Wedge at 0x7a8e5631b820>,
#   <matplotlib.patches.Wedge at 0x7a8e5631bca0>,
#   <matplotlib.patches.Wedge at 0x7a8e56358160>,
#   <matplotlib.patches.Wedge at 0x7a8e563585e0>,
#   <matplotlib.patches.Wedge at 0x7a8e56358a60>,
#   <matplotlib.patches.Wedge at 0x7a8e56358ee0>,
#   <matplotlib.patches.Wedge at 0x7a8e56359360>,
#   <matplotlib.patches.Wedge at 0x7a8e563597e0>,
#   <matplotlib.patches.Wedge at 0x7a8e56359c60>,
#   <matplotlib.patches.Wedge at 0x7a8e5635a0e0>,
#   <matplotlib.patches.Wedge at 0x7a8e5635a560>,
#   <matplotlib.patches.Wedge at 0x7a8e5635a9e0>,
#   <matplotlib.patches.Wedge at 0x7a8e5635ae60>,
#   <matplotlib.patches.Wedge at 0x7a8e5635b2e0>,
#   <matplotlib.patches.Wedge at 0x7a8e5635b760>,
#   <matplotlib.patches.Wedge at 0x7a8e5635bbe0>,
#   <matplotlib.patches.Wedge at 0x7a8e561940a0>,
#   <matplotlib.patches.Wedge at 0x7a8e56194520>,
#   <matplotlib.patches.Wedge at 0x7a8e561949a0>,
#   <matplotlib.patches.Wedge at 0x7a8e56194e20>,
#   <matplotlib.patches.Wedge at 0x7a8e561952a0>,
#   <matplotlib.patches.Wedge at 0x7a8e56195720>,
#   <matplotlib.patches.Wedge at 0x7a8e56195ba0>,
#   <matplotlib.patches.Wedge at 0x7a8e56196020>,
#   <matplotlib.patches.Wedge at 0x7a8e561964a0>,
#   <matplotlib.patches.Wedge at 0x7a8e56196920>,
#   <matplotlib.patches.Wedge at 0x7a8e56196da0>,
#   <matplotlib.patches.Wedge at 0x7a8e56197220>,
#   <matplotlib.patches.Wedge at 0x7a8e561976a0>,
#   <matplotlib.patches.Wedge at 0x7a8e56197b20>,
#   <matplotlib.patches.Wedge at 0x7a8e56197fa0>,
#   <matplotlib.patches.Wedge at 0x7a8e561cc460>,
#   <matplotlib.patches.Wedge at 0x7a8e561cc8e0>,
#   <matplotlib.patches.Wedge at 0x7a8e561ccd60>,
#   <matplotlib.patches.Wedge at 0x7a8e561cd1e0>,
#   <matplotlib.patches.Wedge at 0x7a8e561cd660>,
#   <matplotlib.patches.Wedge at 0x7a8e561cdae0>,
#   <matplotlib.patches.Wedge at 0x7a8e561cdf60>,
#   <matplotlib.patches.Wedge at 0x7a8e561ce3e0>,
#   <matplotlib.patches.Wedge at 0x7a8e561ce860>,
#   <matplotlib.patches.Wedge at 0x7a8e561cece0>,
#   <matplotlib.patches.Wedge at 0x7a8e561cf160>,
#   <matplotlib.patches.Wedge at 0x7a8e561cf5e0>,
#   <matplotlib.patches.Wedge at 0x7a8e561cfa60>,
#   <matplotlib.patches.Wedge at 0x7a8e561cfee0>,
#   <matplotlib.patches.Wedge at 0x7a8e562003a0>,
#   <matplotlib.patches.Wedge at 0x7a8e56200820>,
#   <matplotlib.patches.Wedge at 0x7a8e56200ca0>,
#   <matplotlib.patches.Wedge at 0x7a8e56201120>,
#   <matplotlib.patches.Wedge at 0x7a8e562015a0>,
#   <matplotlib.patches.Wedge at 0x7a8e56201a20>,
#   <matplotlib.patches.Wedge at 0x7a8e56201ea0>,
#   <matplotlib.patches.Wedge at 0x7a8e56202320>,
#   <matplotlib.patches.Wedge at 0x7a8e562027a0>,
#   <matplotlib.patches.Wedge at 0x7a8e56202c20>,
#   <matplotlib.patches.Wedge at 0x7a8e562030a0>,
#   <matplotlib.patches.Wedge at 0x7a8e56203520>,
#   <matplotlib.patches.Wedge at 0x7a8e562039a0>,
#   <matplotlib.patches.Wedge at 0x7a8e56203e20>,
#   <matplotlib.patches.Wedge at 0x7a8e5623c2e0>,
#   <matplotlib.patches.Wedge at 0x7a8e5623c760>,
#   <matplotlib.patches.Wedge at 0x7a8e5623cbe0>,
#   <matplotlib.patches.Wedge at 0x7a8e5623d060>,
#   <matplotlib.patches.Wedge at 0x7a8e5623d4e0>,
#   <matplotlib.patches.Wedge at 0x7a8e5623d960>,
#   <matplotlib.patches.Wedge at 0x7a8e5623dde0>,
#   <matplotlib.patches.Wedge at 0x7a8e5623e260>,
#   <matplotlib.patches.Wedge at 0x7a8e5623e6e0>,
#   <matplotlib.patches.Wedge at 0x7a8e5623eb60>,
#   <matplotlib.patches.Wedge at 0x7a8e5623efe0>,
#   <matplotlib.patches.Wedge at 0x7a8e5623f460>,
#   <matplotlib.patches.Wedge at 0x7a8e5623f8e0>,
#   <matplotlib.patches.Wedge at 0x7a8e5623fd60>,
#   <matplotlib.patches.Wedge at 0x7a8e5627c220>,
#   <matplotlib.patches.Wedge at 0x7a8e5627c6a0>,
#   <matplotlib.patches.Wedge at 0x7a8e5627cb20>,
#   <matplotlib.patches.Wedge at 0x7a8e5627cfa0>,
#   <matplotlib.patches.Wedge at 0x7a8e5627d420>,
#   <matplotlib.patches.Wedge at 0x7a8e5627d8a0>,
#   <matplotlib.patches.Wedge at 0x7a8e5627dd20>,
#   <matplotlib.patches.Wedge at 0x7a8e5627e1a0>,
#   <matplotlib.patches.Wedge at 0x7a8e5627e620>,
#   <matplotlib.patches.Wedge at 0x7a8e5627eaa0>,
#   <matplotlib.patches.Wedge at 0x7a8e5627ef20>,
#   <matplotlib.patches.Wedge at 0x7a8e5627f3a0>,
#   <matplotlib.patches.Wedge at 0x7a8e5627f820>,
#   <matplotlib.patches.Wedge at 0x7a8e5627fca0>,
#   <matplotlib.patches.Wedge at 0x7a8e560ac190>,
#   <matplotlib.patches.Wedge at 0x7a8e560ac6a0>,
#   <matplotlib.patches.Wedge at 0x7a8e560acb20>,
#   <matplotlib.patches.Wedge at 0x7a8e560acfa0>,
#   <matplotlib.patches.Wedge at 0x7a8e560ad420>,
#   <matplotlib.patches.Wedge at 0x7a8e560ad8a0>,
#   <matplotlib.patches.Wedge at 0x7a8e560add20>,
#   <matplotlib.patches.Wedge at 0x7a8e560ae1a0>,
#   <matplotlib.patches.Wedge at 0x7a8e560ae620>,
#   <matplotlib.patches.Wedge at 0x7a8e560aeaa0>,
#   <matplotlib.patches.Wedge at 0x7a8e560aef20>,
#   <matplotlib.patches.Wedge at 0x7a8e560af3a0>,
#   <matplotlib.patches.Wedge at 0x7a8e560af790>,
#   <matplotlib.patches.Wedge at 0x7a8e560afbb0>,
#   <matplotlib.patches.Wedge at 0x7a8e560f0070>,
#   <matplotlib.patches.Wedge at 0x7a8e560f04f0>,
#   <matplotlib.patches.Wedge at 0x7a8e560f0970>,
#   <matplotlib.patches.Wedge at 0x7a8e560f0df0>,
#   <matplotlib.patches.Wedge at 0x7a8e560f1270>,
#   <matplotlib.patches.Wedge at 0x7a8e560f16f0>,
#   <matplotlib.patches.Wedge at 0x7a8e560f1b70>,
#   <matplotlib.patches.Wedge at 0x7a8e560f1ff0>,
#   <matplotlib.patches.Wedge at 0x7a8e560f2470>,
#   <matplotlib.patches.Wedge at 0x7a8e560f28f0>,
#   <matplotlib.patches.Wedge at 0x7a8e560f2d70>,
#   <matplotlib.patches.Wedge at 0x7a8e560f31f0>,
#   <matplotlib.patches.Wedge at 0x7a8e560f3670>,
#   <matplotlib.patches.Wedge at 0x7a8e560f3af0>,
#   <matplotlib.patches.Wedge at 0x7a8e560f3f70>,
#   <matplotlib.patches.Wedge at 0x7a8e5612c430>,
#   <matplotlib.patches.Wedge at 0x7a8e5612c8b0>,
#   <matplotlib.patches.Wedge at 0x7a8e5612cd30>,
#   <matplotlib.patches.Wedge at 0x7a8e5612d1b0>,
#   <matplotlib.patches.Wedge at 0x7a8e5612d630>,
#   <matplotlib.patches.Wedge at 0x7a8e5612dab0>,
#   <matplotlib.patches.Wedge at 0x7a8e5612df30>,
#   <matplotlib.patches.Wedge at 0x7a8e5612e3b0>,
#   <matplotlib.patches.Wedge at 0x7a8e5612e830>,
#   <matplotlib.patches.Wedge at 0x7a8e5612ed70>,
#   <matplotlib.patches.Wedge at 0x7a8e5612f160>,
#   <matplotlib.patches.Wedge at 0x7a8e5612f5e0>,
#   <matplotlib.patches.Wedge at 0x7a8e5612fa60>,
#   <matplotlib.patches.Wedge at 0x7a8e5612fee0>,
#   <matplotlib.patches.Wedge at 0x7a8e5616c3a0>,
#   <matplotlib.patches.Wedge at 0x7a8e5616c820>,
#   <matplotlib.patches.Wedge at 0x7a8e5616cca0>,
#   <matplotlib.patches.Wedge at 0x7a8e5616d120>,
#   <matplotlib.patches.Wedge at 0x7a8e5616d5a0>,
#   <matplotlib.patches.Wedge at 0x7a8e5616da20>,
#   <matplotlib.patches.Wedge at 0x7a8e5616dea0>,
#   <matplotlib.patches.Wedge at 0x7a8e5616e320>,
#   <matplotlib.patches.Wedge at 0x7a8e5616e7a0>,
#   <matplotlib.patches.Wedge at 0x7a8e5616ec20>,
#   <matplotlib.patches.Wedge at 0x7a8e5616f0a0>,
#   <matplotlib.patches.Wedge at 0x7a8e5616f520>,
#   <matplotlib.patches.Wedge at 0x7a8e5616f9a0>,
#   <matplotlib.patches.Wedge at 0x7a8e5616fe20>,
#   <matplotlib.patches.Wedge at 0x7a8e55fa02e0>,
#   <matplotlib.patches.Wedge at 0x7a8e55fa0760>,
#   <matplotlib.patches.Wedge at 0x7a8e55fa0be0>,
#   <matplotlib.patches.Wedge at 0x7a8e55fa1060>,
#   <matplotlib.patches.Wedge at 0x7a8e55fa14e0>,
#   <matplotlib.patches.Wedge at 0x7a8e55fa1960>,
#   <matplotlib.patches.Wedge at 0x7a8e55fa1de0>,
#   <matplotlib.patches.Wedge at 0x7a8e55fa2260>,
#   <matplotlib.patches.Wedge at 0x7a8e55fa26e0>,
#   <matplotlib.patches.Wedge at 0x7a8e55fa2b60>,
#   <matplotlib.patches.Wedge at 0x7a8e55fa2fe0>,
#   <matplotlib.patches.Wedge at 0x7a8e55fa3460>,
#   <matplotlib.patches.Wedge at 0x7a8e55fa38e0>,
#   <matplotlib.patches.Wedge at 0x7a8e55fa3d60>,
#   <matplotlib.patches.Wedge at 0x7a8e55fd8220>,
#   <matplotlib.patches.Wedge at 0x7a8e55fd86a0>,
#   <matplotlib.patches.Wedge at 0x7a8e55fd8b20>,
#   <matplotlib.patches.Wedge at 0x7a8e55fd8fa0>,
#   <matplotlib.patches.Wedge at 0x7a8e55fd9420>,
#   <matplotlib.patches.Wedge at 0x7a8e55fd98a0>,
#   <matplotlib.patches.Wedge at 0x7a8e55fd9d20>,
#   <matplotlib.patches.Wedge at 0x7a8e55fda1a0>,
#   <matplotlib.patches.Wedge at 0x7a8e55fda620>,
#   <matplotlib.patches.Wedge at 0x7a8e55fdaaa0>,
#   <matplotlib.patches.Wedge at 0x7a8e55fdaf20>,
#   <matplotlib.patches.Wedge at 0x7a8e55fdb3a0>,
#   <matplotlib.patches.Wedge at 0x7a8e55fdb820>,
#   <matplotlib.patches.Wedge at 0x7a8e55fdbca0>,
#   <matplotlib.patches.Wedge at 0x7a8e56014160>,
#   <matplotlib.patches.Wedge at 0x7a8e560145e0>,
#   <matplotlib.patches.Wedge at 0x7a8e56014a60>,
#   <matplotlib.patches.Wedge at 0x7a8e56014ee0>,
#   <matplotlib.patches.Wedge at 0x7a8e56015360>,
#   <matplotlib.patches.Wedge at 0x7a8e560157e0>,
#   <matplotlib.patches.Wedge at 0x7a8e56015c60>,
#   <matplotlib.patches.Wedge at 0x7a8e560160e0>,
#   <matplotlib.patches.Wedge at 0x7a8e56016560>,
#   <matplotlib.patches.Wedge at 0x7a8e560169e0>,
#   <matplotlib.patches.Wedge at 0x7a8e56016e60>,
#   <matplotlib.patches.Wedge at 0x7a8e560172e0>,
#   <matplotlib.patches.Wedge at 0x7a8e56017760>,
#   <matplotlib.patches.Wedge at 0x7a8e56017be0>,
#   <matplotlib.patches.Wedge at 0x7a8e560540a0>,
#   <matplotlib.patches.Wedge at 0x7a8e56054520>,
#   <matplotlib.patches.Wedge at 0x7a8e560549a0>,
#   <matplotlib.patches.Wedge at 0x7a8e56054e20>,
#   <matplotlib.patches.Wedge at 0x7a8e560552a0>,
#   <matplotlib.patches.Wedge at 0x7a8e56055720>,
#   <matplotlib.patches.Wedge at 0x7a8e56055ba0>,
#   <matplotlib.patches.Wedge at 0x7a8e56056020>,
#   <matplotlib.patches.Wedge at 0x7a8e560564a0>,
#   <matplotlib.patches.Wedge at 0x7a8e56056920>,
#   <matplotlib.patches.Wedge at 0x7a8e56056da0>,
#   <matplotlib.patches.Wedge at 0x7a8e56057220>,
#   <matplotlib.patches.Wedge at 0x7a8e560576a0>,
#   <matplotlib.patches.Wedge at 0x7a8e56057b20>,
#   <matplotlib.patches.Wedge at 0x7a8e56057fa0>,
#   <matplotlib.patches.Wedge at 0x7a8e56084460>,
#   <matplotlib.patches.Wedge at 0x7a8e560848e0>,
#   <matplotlib.patches.Wedge at 0x7a8e56084d60>,
#   <matplotlib.patches.Wedge at 0x7a8e560851e0>,
#   <matplotlib.patches.Wedge at 0x7a8e56085660>,
#   <matplotlib.patches.Wedge at 0x7a8e56085ae0>,
#   <matplotlib.patches.Wedge at 0x7a8e56085f60>,
#   <matplotlib.patches.Wedge at 0x7a8e560863e0>,
#   <matplotlib.patches.Wedge at 0x7a8e56086860>,
#   <matplotlib.patches.Wedge at 0x7a8e56086ce0>,
#   <matplotlib.patches.Wedge at 0x7a8e56087160>,
#   <matplotlib.patches.Wedge at 0x7a8e560875e0>,
#   <matplotlib.patches.Wedge at 0x7a8e56087a60>,
#   <matplotlib.patches.Wedge at 0x7a8e56087ee0>,
#   <matplotlib.patches.Wedge at 0x7a8e55ec83a0>,
#   <matplotlib.patches.Wedge at 0x7a8e55ec8820>,
#   <matplotlib.patches.Wedge at 0x7a8e55ec8ca0>,
#   <matplotlib.patches.Wedge at 0x7a8e55ec9120>,
#   <matplotlib.patches.Wedge at 0x7a8e55ec95a0>,
#   <matplotlib.patches.Wedge at 0x7a8e55ec9a20>,
#   <matplotlib.patches.Wedge at 0x7a8e55ec9ea0>,
#   <matplotlib.patches.Wedge at 0x7a8e55eca320>,
#   <matplotlib.patches.Wedge at 0x7a8e55eca7a0>,
#   <matplotlib.patches.Wedge at 0x7a8e55ecac20>,
#   <matplotlib.patches.Wedge at 0x7a8e55ecb0a0>,
#   <matplotlib.patches.Wedge at 0x7a8e55ecb520>,
#   <matplotlib.patches.Wedge at 0x7a8e55ecb9a0>,
#   <matplotlib.patches.Wedge at 0x7a8e55ecbe20>,
#   <matplotlib.patches.Wedge at 0x7a8e55f042e0>,
#   <matplotlib.patches.Wedge at 0x7a8e55f04760>,
#   <matplotlib.patches.Wedge at 0x7a8e55f04be0>,
#   <matplotlib.patches.Wedge at 0x7a8e55f05060>,
#   <matplotlib.patches.Wedge at 0x7a8e55f054e0>,
#   <matplotlib.patches.Wedge at 0x7a8e55f05960>,
#   <matplotlib.patches.Wedge at 0x7a8e55f05de0>,
#   <matplotlib.patches.Wedge at 0x7a8e55f06260>,
#   <matplotlib.patches.Wedge at 0x7a8e55f066e0>,
#   <matplotlib.patches.Wedge at 0x7a8e55f06b60>,
#   <matplotlib.patches.Wedge at 0x7a8e55f06fe0>,
#   <matplotlib.patches.Wedge at 0x7a8e55f07460>,
#   <matplotlib.patches.Wedge at 0x7a8e55f078e0>,
#   <matplotlib.patches.Wedge at 0x7a8e55f07d60>,
#   <matplotlib.patches.Wedge at 0x7a8e55f40220>,
#   <matplotlib.patches.Wedge at 0x7a8e55f406a0>,
#   <matplotlib.patches.Wedge at 0x7a8e55f40b20>,
#   <matplotlib.patches.Wedge at 0x7a8e55f40fa0>,
#   <matplotlib.patches.Wedge at 0x7a8e55f41420>,
#   <matplotlib.patches.Wedge at 0x7a8e55f418a0>,
#   <matplotlib.patches.Wedge at 0x7a8e55f41d20>,
#   <matplotlib.patches.Wedge at 0x7a8e55f421a0>,
#   <matplotlib.patches.Wedge at 0x7a8e55f42620>,
#   <matplotlib.patches.Wedge at 0x7a8e55f42aa0>,
#   <matplotlib.patches.Wedge at 0x7a8e55f42f20>,
#   <matplotlib.patches.Wedge at 0x7a8e55f433a0>,
#   <matplotlib.patches.Wedge at 0x7a8e55f43820>,
#   <matplotlib.patches.Wedge at 0x7a8e55f43ca0>,
#   <matplotlib.patches.Wedge at 0x7a8e55f78160>,
#   <matplotlib.patches.Wedge at 0x7a8e55f785e0>,
#   <matplotlib.patches.Wedge at 0x7a8e55f78a60>,
#   <matplotlib.patches.Wedge at 0x7a8e55f78ee0>,
#   <matplotlib.patches.Wedge at 0x7a8e55f79360>,
#   <matplotlib.patches.Wedge at 0x7a8e55f797e0>,
#   <matplotlib.patches.Wedge at 0x7a8e55f79c60>,
#   <matplotlib.patches.Wedge at 0x7a8e55f7a0e0>,
#   <matplotlib.patches.Wedge at 0x7a8e55f7a560>,
#   <matplotlib.patches.Wedge at 0x7a8e55f7a9e0>,
#   <matplotlib.patches.Wedge at 0x7a8e55f7ae60>,
#   <matplotlib.patches.Wedge at 0x7a8e55f7b2e0>,
#   <matplotlib.patches.Wedge at 0x7a8e55f7b760>,
#   <matplotlib.patches.Wedge at 0x7a8e55f7bbe0>,
#   <matplotlib.patches.Wedge at 0x7a8e55db00a0>,
#   <matplotlib.patches.Wedge at 0x7a8e55db0520>,
#   <matplotlib.patches.Wedge at 0x7a8e55db09a0>,
#   <matplotlib.patches.Wedge at 0x7a8e55db0e20>,
#   <matplotlib.patches.Wedge at 0x7a8e55db12a0>,
#   <matplotlib.patches.Wedge at 0x7a8e55db1720>,
#   <matplotlib.patches.Wedge at 0x7a8e55db1ba0>,
#   <matplotlib.patches.Wedge at 0x7a8e55db2020>,
#   <matplotlib.patches.Wedge at 0x7a8e55db24a0>,
#   <matplotlib.patches.Wedge at 0x7a8e55db2920>,
#   <matplotlib.patches.Wedge at 0x7a8e55db2da0>,
#   <matplotlib.patches.Wedge at 0x7a8e55db3220>,
#   <matplotlib.patches.Wedge at 0x7a8e55db36a0>,
#   <matplotlib.patches.Wedge at 0x7a8e55db3b20>,
#   <matplotlib.patches.Wedge at 0x7a8e55db3fa0>,
#   <matplotlib.patches.Wedge at 0x7a8e55df0460>,
#   <matplotlib.patches.Wedge at 0x7a8e55df08e0>,
#   <matplotlib.patches.Wedge at 0x7a8e55df0d60>,
#   <matplotlib.patches.Wedge at 0x7a8e55df11e0>,
#   <matplotlib.patches.Wedge at 0x7a8e55df1660>,
#   <matplotlib.patches.Wedge at 0x7a8e55df1ae0>,
#   <matplotlib.patches.Wedge at 0x7a8e55df1f60>,
#   <matplotlib.patches.Wedge at 0x7a8e55df23e0>,
#   <matplotlib.patches.Wedge at 0x7a8e55df2860>,
#   <matplotlib.patches.Wedge at 0x7a8e55df2ce0>,
#   <matplotlib.patches.Wedge at 0x7a8e55df3160>,
#   <matplotlib.patches.Wedge at 0x7a8e55df35e0>,
#   <matplotlib.patches.Wedge at 0x7a8e55df3a60>,
#   <matplotlib.patches.Wedge at 0x7a8e55df3ee0>,
#   <matplotlib.patches.Wedge at 0x7a8e55e2c3a0>,
#   <matplotlib.patches.Wedge at 0x7a8e55e2c820>,
#   <matplotlib.patches.Wedge at 0x7a8e55e2cca0>,
#   <matplotlib.patches.Wedge at 0x7a8e55e2d120>,
#   <matplotlib.patches.Wedge at 0x7a8e55e2d5a0>,
#   <matplotlib.patches.Wedge at 0x7a8e55e2da20>,
#   <matplotlib.patches.Wedge at 0x7a8e55e2dea0>,
#   <matplotlib.patches.Wedge at 0x7a8e55e2e320>,
#   <matplotlib.patches.Wedge at 0x7a8e55e2e7a0>,
#   <matplotlib.patches.Wedge at 0x7a8e55e2ec20>,
#   <matplotlib.patches.Wedge at 0x7a8e55e2f0a0>,
#   <matplotlib.patches.Wedge at 0x7a8e55e2f520>,
#   <matplotlib.patches.Wedge at 0x7a8e55e2f9a0>,
#   <matplotlib.patches.Wedge at 0x7a8e55e2fe20>,
#   <matplotlib.patches.Wedge at 0x7a8e55e5c2e0>,
#   <matplotlib.patches.Wedge at 0x7a8e55e5c760>,
#   <matplotlib.patches.Wedge at 0x7a8e55e5cbe0>,
#   <matplotlib.patches.Wedge at 0x7a8e55e5d060>,
#   <matplotlib.patches.Wedge at 0x7a8e55e5d4e0>,
#   <matplotlib.patches.Wedge at 0x7a8e55e5d960>,
#   <matplotlib.patches.Wedge at 0x7a8e55e5dde0>,
#   <matplotlib.patches.Wedge at 0x7a8e55e5e260>,
#   <matplotlib.patches.Wedge at 0x7a8e55e5e6e0>,
#   <matplotlib.patches.Wedge at 0x7a8e55e5eb60>,
#   <matplotlib.patches.Wedge at 0x7a8e55e5efe0>,
#   <matplotlib.patches.Wedge at 0x7a8e55e5f460>,
#   <matplotlib.patches.Wedge at 0x7a8e55e5f8e0>,
#   <matplotlib.patches.Wedge at 0x7a8e55e5fd60>,
#   <matplotlib.patches.Wedge at 0x7a8e55c9c220>,
#   <matplotlib.patches.Wedge at 0x7a8e55c9c6a0>,
#   <matplotlib.patches.Wedge at 0x7a8e55c9cb20>,
#   <matplotlib.patches.Wedge at 0x7a8e55c9cfa0>,
#   <matplotlib.patches.Wedge at 0x7a8e55c9d420>,
#   <matplotlib.patches.Wedge at 0x7a8e55c9d8a0>,
#   <matplotlib.patches.Wedge at 0x7a8e55c9dd20>,
#   <matplotlib.patches.Wedge at 0x7a8e55c9e1a0>,
#   <matplotlib.patches.Wedge at 0x7a8e55c9e620>,
#   <matplotlib.patches.Wedge at 0x7a8e55c9eaa0>,
#   <matplotlib.patches.Wedge at 0x7a8e55c9ef20>,
#   <matplotlib.patches.Wedge at 0x7a8e55c9f3a0>,
#   <matplotlib.patches.Wedge at 0x7a8e55c9f820>,
#   <matplotlib.patches.Wedge at 0x7a8e55c9fca0>,
#   <matplotlib.patches.Wedge at 0x7a8e55cd8160>,
#   <matplotlib.patches.Wedge at 0x7a8e55cd85e0>,
#   <matplotlib.patches.Wedge at 0x7a8e55cd8a60>,
#   <matplotlib.patches.Wedge at 0x7a8e55cd8ee0>,
#   <matplotlib.patches.Wedge at 0x7a8e55cd9360>,
#   <matplotlib.patches.Wedge at 0x7a8e55cd97e0>,
#   <matplotlib.patches.Wedge at 0x7a8e55cd9c60>,
#   <matplotlib.patches.Wedge at 0x7a8e55cda0e0>,
#   <matplotlib.patches.Wedge at 0x7a8e55cda560>,
#   <matplotlib.patches.Wedge at 0x7a8e55cda9e0>,
#   <matplotlib.patches.Wedge at 0x7a8e55cdae60>,
#   <matplotlib.patches.Wedge at 0x7a8e55cdb2e0>,
#   <matplotlib.patches.Wedge at 0x7a8e55cdb760>,
#   <matplotlib.patches.Wedge at 0x7a8e55cdbbe0>,
#   <matplotlib.patches.Wedge at 0x7a8e55d180a0>,
#   <matplotlib.patches.Wedge at 0x7a8e55d18520>,
#   <matplotlib.patches.Wedge at 0x7a8e55d189a0>,
#   <matplotlib.patches.Wedge at 0x7a8e55d18e20>,
#   <matplotlib.patches.Wedge at 0x7a8e55d192a0>,
#   <matplotlib.patches.Wedge at 0x7a8e55d19720>,
#   <matplotlib.patches.Wedge at 0x7a8e55d19ba0>,
#   <matplotlib.patches.Wedge at 0x7a8e55d1a020>,
#   <matplotlib.patches.Wedge at 0x7a8e55d1a4a0>,
#   <matplotlib.patches.Wedge at 0x7a8e55d1a920>,
#   <matplotlib.patches.Wedge at 0x7a8e55d1ada0>,
#   <matplotlib.patches.Wedge at 0x7a8e55d1b220>,
#   <matplotlib.patches.Wedge at 0x7a8e55d1b6a0>,
#   <matplotlib.patches.Wedge at 0x7a8e55d1bb20>,
#   <matplotlib.patches.Wedge at 0x7a8e55d1bfa0>,
#   <matplotlib.patches.Wedge at 0x7a8e55d48460>,
#   <matplotlib.patches.Wedge at 0x7a8e55d488e0>,
#   <matplotlib.patches.Wedge at 0x7a8e55d48d60>,
#   <matplotlib.patches.Wedge at 0x7a8e55d491e0>,
#   <matplotlib.patches.Wedge at 0x7a8e55d49660>,
#   <matplotlib.patches.Wedge at 0x7a8e55d49ae0>,
#   <matplotlib.patches.Wedge at 0x7a8e55d49f60>,
#   <matplotlib.patches.Wedge at 0x7a8e55d4a3e0>,
#   <matplotlib.patches.Wedge at 0x7a8e55d4a860>,
#   <matplotlib.patches.Wedge at 0x7a8e55d4ace0>,
#   <matplotlib.patches.Wedge at 0x7a8e55d4b160>,
#   <matplotlib.patches.Wedge at 0x7a8e55d4b5e0>,
#   <matplotlib.patches.Wedge at 0x7a8e55d4ba60>,
#   <matplotlib.patches.Wedge at 0x7a8e55d4bee0>,
#   <matplotlib.patches.Wedge at 0x7a8e55d843a0>,
#   <matplotlib.patches.Wedge at 0x7a8e55d84820>,
#   <matplotlib.patches.Wedge at 0x7a8e55d84ca0>,
#   <matplotlib.patches.Wedge at 0x7a8e55d85120>,
#   <matplotlib.patches.Wedge at 0x7a8e55d855a0>,
#   <matplotlib.patches.Wedge at 0x7a8e55d85a20>,
#   <matplotlib.patches.Wedge at 0x7a8e55d85ea0>,
#   <matplotlib.patches.Wedge at 0x7a8e55d86320>,
#   <matplotlib.patches.Wedge at 0x7a8e55d867a0>,
#   <matplotlib.patches.Wedge at 0x7a8e55d86c20>,
#   <matplotlib.patches.Wedge at 0x7a8e55d870a0>,
#   <matplotlib.patches.Wedge at 0x7a8e55d87520>,
#   <matplotlib.patches.Wedge at 0x7a8e55d879a0>,
#   <matplotlib.patches.Wedge at 0x7a8e55d87e20>,
#   <matplotlib.patches.Wedge at 0x7a8e55bc42e0>,
#   <matplotlib.patches.Wedge at 0x7a8e55bc4760>,
#   <matplotlib.patches.Wedge at 0x7a8e55bc4be0>,
#   <matplotlib.patches.Wedge at 0x7a8e55bc5060>,
#   <matplotlib.patches.Wedge at 0x7a8e55bc54e0>,
#   <matplotlib.patches.Wedge at 0x7a8e55bc5960>,
#   <matplotlib.patches.Wedge at 0x7a8e55bc5de0>,
#   <matplotlib.patches.Wedge at 0x7a8e55bc6260>,
#   <matplotlib.patches.Wedge at 0x7a8e55bc66e0>,
#   <matplotlib.patches.Wedge at 0x7a8e55bc6b60>,
#   <matplotlib.patches.Wedge at 0x7a8e55bc6fe0>,
#   <matplotlib.patches.Wedge at 0x7a8e55bc7460>,
#   <matplotlib.patches.Wedge at 0x7a8e55bc78e0>,
#   <matplotlib.patches.Wedge at 0x7a8e55bc7d60>,
#   <matplotlib.patches.Wedge at 0x7a8e55bfc220>,
#   <matplotlib.patches.Wedge at 0x7a8e55bfc6a0>,
#   <matplotlib.patches.Wedge at 0x7a8e55bfcb20>,
#   <matplotlib.patches.Wedge at 0x7a8e55bfcfa0>,
#   <matplotlib.patches.Wedge at 0x7a8e55bfd420>,
#   <matplotlib.patches.Wedge at 0x7a8e55bfd8a0>,
#   <matplotlib.patches.Wedge at 0x7a8e55bfdd20>,
#   <matplotlib.patches.Wedge at 0x7a8e55bfe1a0>,
#   <matplotlib.patches.Wedge at 0x7a8e55bfe620>,
#   <matplotlib.patches.Wedge at 0x7a8e55bfeaa0>,
#   <matplotlib.patches.Wedge at 0x7a8e55bfef20>,
#   <matplotlib.patches.Wedge at 0x7a8e55bff3a0>,
#   <matplotlib.patches.Wedge at 0x7a8e55bff820>,
#   <matplotlib.patches.Wedge at 0x7a8e55bffca0>,
#   <matplotlib.patches.Wedge at 0x7a8e55c30160>,
#   <matplotlib.patches.Wedge at 0x7a8e55c305e0>,
#   <matplotlib.patches.Wedge at 0x7a8e55c30a60>,
#   <matplotlib.patches.Wedge at 0x7a8e55c30ee0>,
#   <matplotlib.patches.Wedge at 0x7a8e55c31360>,
#   <matplotlib.patches.Wedge at 0x7a8e55c317e0>,
#   <matplotlib.patches.Wedge at 0x7a8e55c31c60>,
#   <matplotlib.patches.Wedge at 0x7a8e55c320e0>,
#   <matplotlib.patches.Wedge at 0x7a8e55c32560>,
#   <matplotlib.patches.Wedge at 0x7a8e55c329e0>,
#   <matplotlib.patches.Wedge at 0x7a8e55c32e60>,
#   <matplotlib.patches.Wedge at 0x7a8e55c332e0>,
#   <matplotlib.patches.Wedge at 0x7a8e55c33760>,
#   <matplotlib.patches.Wedge at 0x7a8e55c33be0>,
#   <matplotlib.patches.Wedge at 0x7a8e55c740a0>,
#   <matplotlib.patches.Wedge at 0x7a8e55c74520>,
#   <matplotlib.patches.Wedge at 0x7a8e55c749a0>,
#   <matplotlib.patches.Wedge at 0x7a8e55c74e20>,
#   <matplotlib.patches.Wedge at 0x7a8e55c752a0>,
#   <matplotlib.patches.Wedge at 0x7a8e55c75720>,
#   <matplotlib.patches.Wedge at 0x7a8e55c75c90>,
#   <matplotlib.patches.Wedge at 0x7a8e55c76110>,
#   <matplotlib.patches.Wedge at 0x7a8e55c76590>,
#   <matplotlib.patches.Wedge at 0x7a8e55c76a10>,
#   <matplotlib.patches.Wedge at 0x7a8e55c76e90>,
#   <matplotlib.patches.Wedge at 0x7a8e55c77310>,
#   <matplotlib.patches.Wedge at 0x7a8e55c77790>,
#   <matplotlib.patches.Wedge at 0x7a8e55c77c10>,
#   <matplotlib.patches.Wedge at 0x7a8e55ab00d0>,
#   <matplotlib.patches.Wedge at 0x7a8e55ab0550>,
#   <matplotlib.patches.Wedge at 0x7a8e55ab08b0>,
#   <matplotlib.patches.Wedge at 0x7a8e55ab0d90>,
#   <matplotlib.patches.Wedge at 0x7a8e55ab11b0>,
#   <matplotlib.patches.Wedge at 0x7a8e55ab1630>,
#   <matplotlib.patches.Wedge at 0x7a8e55ab1ab0>,
#   <matplotlib.patches.Wedge at 0x7a8e55ab1f30>,
#   <matplotlib.patches.Wedge at 0x7a8e55ab23b0>,
#   <matplotlib.patches.Wedge at 0x7a8e55ab2830>,
#   <matplotlib.patches.Wedge at 0x7a8e55ab2cb0>,
#   <matplotlib.patches.Wedge at 0x7a8e55ab3130>,
#   <matplotlib.patches.Wedge at 0x7a8e55ab35b0>,
#   <matplotlib.patches.Wedge at 0x7a8e55ab3a30>,
#   <matplotlib.patches.Wedge at 0x7a8e55ab3eb0>,
#   <matplotlib.patches.Wedge at 0x7a8e55aec370>,
#   <matplotlib.patches.Wedge at 0x7a8e55aec7f0>,
#   <matplotlib.patches.Wedge at 0x7a8e55aecc70>,
#   <matplotlib.patches.Wedge at 0x7a8e55aed0f0>,
#   <matplotlib.patches.Wedge at 0x7a8e55aed570>,
#   <matplotlib.patches.Wedge at 0x7a8e55aed9f0>,
#   <matplotlib.patches.Wedge at 0x7a8e55aede70>,
#   <matplotlib.patches.Wedge at 0x7a8e55aee2f0>,
#   <matplotlib.patches.Wedge at 0x7a8e55aee770>,
#   <matplotlib.patches.Wedge at 0x7a8e55aeebf0>,
#   <matplotlib.patches.Wedge at 0x7a8e55aef070>,
#   <matplotlib.patches.Wedge at 0x7a8e55aef4f0>,
#   <matplotlib.patches.Wedge at 0x7a8e55aef970>,
#   <matplotlib.patches.Wedge at 0x7a8e55aefdf0>,
#   <matplotlib.patches.Wedge at 0x7a8e55b202b0>,
#   <matplotlib.patches.Wedge at 0x7a8e55b20730>,
#   <matplotlib.patches.Wedge at 0x7a8e55b20bb0>,
#   <matplotlib.patches.Wedge at 0x7a8e55b21030>,
#   <matplotlib.patches.Wedge at 0x7a8e55b214b0>,
#   <matplotlib.patches.Wedge at 0x7a8e55b21960>,
#   <matplotlib.patches.Wedge at 0x7a8e55b21de0>,
#   <matplotlib.patches.Wedge at 0x7a8e55b22260>,
#   <matplotlib.patches.Wedge at 0x7a8e55b226e0>,
#   <matplotlib.patches.Wedge at 0x7a8e55b22b60>,
#   <matplotlib.patches.Wedge at 0x7a8e55b22fe0>,
#   <matplotlib.patches.Wedge at 0x7a8e55b23460>,
#   <matplotlib.patches.Wedge at 0x7a8e55b238e0>,
#   <matplotlib.patches.Wedge at 0x7a8e55b23d60>,
#   <matplotlib.patches.Wedge at 0x7a8e55b60220>,
#   <matplotlib.patches.Wedge at 0x7a8e55b606a0>,
#   <matplotlib.patches.Wedge at 0x7a8e55b60b20>,
#   <matplotlib.patches.Wedge at 0x7a8e55b60fa0>,
#   <matplotlib.patches.Wedge at 0x7a8e55b61420>,
#   <matplotlib.patches.Wedge at 0x7a8e55b618a0>,
#   <matplotlib.patches.Wedge at 0x7a8e55b61d20>,
#   <matplotlib.patches.Wedge at 0x7a8e55b621a0>,
#   <matplotlib.patches.Wedge at 0x7a8e55b62620>,
#   <matplotlib.patches.Wedge at 0x7a8e55b62aa0>,
#   <matplotlib.patches.Wedge at 0x7a8e55b62f20>,
#   <matplotlib.patches.Wedge at 0x7a8e55b633a0>,
#   <matplotlib.patches.Wedge at 0x7a8e55b63820>,
#   <matplotlib.patches.Wedge at 0x7a8e55b63ca0>,
#   <matplotlib.patches.Wedge at 0x7a8e55998160>,
#   <matplotlib.patches.Wedge at 0x7a8e559985e0>,
#   <matplotlib.patches.Wedge at 0x7a8e55998a60>,
#   <matplotlib.patches.Wedge at 0x7a8e55998ee0>,
#   <matplotlib.patches.Wedge at 0x7a8e55999360>,
#   <matplotlib.patches.Wedge at 0x7a8e559997e0>,
#   <matplotlib.patches.Wedge at 0x7a8e55999c60>,
#   <matplotlib.patches.Wedge at 0x7a8e5599a0e0>,
#   <matplotlib.patches.Wedge at 0x7a8e5599a560>,
#   <matplotlib.patches.Wedge at 0x7a8e5599a9e0>,
#   <matplotlib.patches.Wedge at 0x7a8e5599ae60>,
#   <matplotlib.patches.Wedge at 0x7a8e5599b2e0>,
#   <matplotlib.patches.Wedge at 0x7a8e5599b760>,
#   <matplotlib.patches.Wedge at 0x7a8e5599bbe0>,
#   <matplotlib.patches.Wedge at 0x7a8e559cc0a0>,
#   <matplotlib.patches.Wedge at 0x7a8e559cc520>,
#   <matplotlib.patches.Wedge at 0x7a8e559cc9a0>,
#   <matplotlib.patches.Wedge at 0x7a8e559cce20>,
#   <matplotlib.patches.Wedge at 0x7a8e559cd2a0>,
#   <matplotlib.patches.Wedge at 0x7a8e559cd720>,
#   <matplotlib.patches.Wedge at 0x7a8e559cdba0>,
#   <matplotlib.patches.Wedge at 0x7a8e559ce020>,
#   <matplotlib.patches.Wedge at 0x7a8e559ce4a0>,
#   <matplotlib.patches.Wedge at 0x7a8e559ce920>,
#   <matplotlib.patches.Wedge at 0x7a8e559ceda0>,
#   <matplotlib.patches.Wedge at 0x7a8e559cf220>,
#   <matplotlib.patches.Wedge at 0x7a8e559cf6a0>,
#   <matplotlib.patches.Wedge at 0x7a8e559cfb20>,
#   <matplotlib.patches.Wedge at 0x7a8e559cffa0>,
#   <matplotlib.patches.Wedge at 0x7a8e55a08460>,
#   <matplotlib.patches.Wedge at 0x7a8e55a088e0>,
#   <matplotlib.patches.Wedge at 0x7a8e55a08d60>,
#   <matplotlib.patches.Wedge at 0x7a8e55a091e0>,
#   <matplotlib.patches.Wedge at 0x7a8e55a09660>,
#   <matplotlib.patches.Wedge at 0x7a8e55a09ae0>,
#   <matplotlib.patches.Wedge at 0x7a8e55a09f60>,
#   <matplotlib.patches.Wedge at 0x7a8e55a0a3e0>,
#   <matplotlib.patches.Wedge at 0x7a8e55a0a860>,
#   <matplotlib.patches.Wedge at 0x7a8e55a0ace0>,
#   <matplotlib.patches.Wedge at 0x7a8e55a0b160>,
#   <matplotlib.patches.Wedge at 0x7a8e55a0b5e0>,
#   <matplotlib.patches.Wedge at 0x7a8e55a0ba60>,
#   <matplotlib.patches.Wedge at 0x7a8e55a0bee0>,
#   <matplotlib.patches.Wedge at 0x7a8e55a483a0>,
#   <matplotlib.patches.Wedge at 0x7a8e55a48820>,
#   <matplotlib.patches.Wedge at 0x7a8e55a48ca0>,
#   <matplotlib.patches.Wedge at 0x7a8e55a49120>,
#   <matplotlib.patches.Wedge at 0x7a8e55a495a0>,
#   <matplotlib.patches.Wedge at 0x7a8e55a49a20>,
#   <matplotlib.patches.Wedge at 0x7a8e55a49ea0>,
#   <matplotlib.patches.Wedge at 0x7a8e55a4a320>,
#   <matplotlib.patches.Wedge at 0x7a8e55a4a7a0>,
#   <matplotlib.patches.Wedge at 0x7a8e55a4ac20>,
#   <matplotlib.patches.Wedge at 0x7a8e55a4b0a0>,
#   <matplotlib.patches.Wedge at 0x7a8e55a4b520>,
#   <matplotlib.patches.Wedge at 0x7a8e55a4b9a0>,
#   <matplotlib.patches.Wedge at 0x7a8e55a4be20>,
#   <matplotlib.patches.Wedge at 0x7a8e55a7c2e0>,
#   <matplotlib.patches.Wedge at 0x7a8e55a7c760>,
#   <matplotlib.patches.Wedge at 0x7a8e55a7cbe0>,
#   <matplotlib.patches.Wedge at 0x7a8e55a7d060>,
#   <matplotlib.patches.Wedge at 0x7a8e55a7d4e0>,
#   <matplotlib.patches.Wedge at 0x7a8e55a7d960>,
#   <matplotlib.patches.Wedge at 0x7a8e55a7dde0>,
#   <matplotlib.patches.Wedge at 0x7a8e55a7e260>,
#   <matplotlib.patches.Wedge at 0x7a8e55a7e6e0>,
#   <matplotlib.patches.Wedge at 0x7a8e55a7eb60>,
#   <matplotlib.patches.Wedge at 0x7a8e55a7efe0>,
#   <matplotlib.patches.Wedge at 0x7a8e55a7f460>,
#   <matplotlib.patches.Wedge at 0x7a8e55a7f8e0>,
#   <matplotlib.patches.Wedge at 0x7a8e55a7fd60>,
#   <matplotlib.patches.Wedge at 0x7a8e558bc220>,
#   <matplotlib.patches.Wedge at 0x7a8e558bc6a0>,
#   <matplotlib.patches.Wedge at 0x7a8e558bcb20>,
#   <matplotlib.patches.Wedge at 0x7a8e558bcfa0>,
#   <matplotlib.patches.Wedge at 0x7a8e558bd420>,
#   <matplotlib.patches.Wedge at 0x7a8e558bd8a0>,
#   <matplotlib.patches.Wedge at 0x7a8e558bdd20>,
#   <matplotlib.patches.Wedge at 0x7a8e558be1a0>,
#   <matplotlib.patches.Wedge at 0x7a8e558be620>,
#   <matplotlib.patches.Wedge at 0x7a8e558beaa0>,
#   <matplotlib.patches.Wedge at 0x7a8e558bef20>,
#   <matplotlib.patches.Wedge at 0x7a8e558bf3a0>,
#   <matplotlib.patches.Wedge at 0x7a8e558bf820>,
#   <matplotlib.patches.Wedge at 0x7a8e558bfca0>,
#   <matplotlib.patches.Wedge at 0x7a8e558f4160>,
#   <matplotlib.patches.Wedge at 0x7a8e558f45e0>,
#   <matplotlib.patches.Wedge at 0x7a8e558f4a60>,
#   <matplotlib.patches.Wedge at 0x7a8e558f4ee0>,
#   <matplotlib.patches.Wedge at 0x7a8e558f5360>,
#   <matplotlib.patches.Wedge at 0x7a8e558f57e0>,
#   <matplotlib.patches.Wedge at 0x7a8e558f5c60>,
#   <matplotlib.patches.Wedge at 0x7a8e558f60e0>,
#   <matplotlib.patches.Wedge at 0x7a8e558f6560>,
#   <matplotlib.patches.Wedge at 0x7a8e558f69e0>,
#   <matplotlib.patches.Wedge at 0x7a8e558f6e60>,
#   <matplotlib.patches.Wedge at 0x7a8e558f72e0>,
#   <matplotlib.patches.Wedge at 0x7a8e558f7760>,
#   <matplotlib.patches.Wedge at 0x7a8e558f7be0>,
# ...
#   Text(-0.5146585768159451, -0.9721761925236527, ''),
#   Text(-0.5103700302289116, -0.9744344165946419, ''),
#   Text(-0.5060715752051617, -0.9766737227802161, ''),
#   Text(-0.4974452738428857, -0.9810954079656966, ''),
#   Text(-0.48878034261756065, -0.9854409047074616, ''),
#   Text(-0.4800774544174904, -0.989709875549407, ''),
#   Text(-0.4757119875369404, -0.9918155599271743, ''),
#   Text(-0.4757119875369404, -0.9918155599271743, ''),
#   Text(-0.47133728507858497, -0.9939019889781632, ''),
#   Text(-0.4625605133318773, -0.998016919448839, ''),
#   Text(-0.4537478207508165, -1.0020543474103014, ''),
#   Text(1.0630392866901766, -0.2827498451869443, ''),
#   Text(1.0642748048941961, -0.27806319365824195, ''),
#   Text(1.0654896610316196, -0.27337114374916094, ''),
#   Text(1.067857293166332, -0.2639712132628764, ''),
#   Text(1.0690100231978859, -0.25926351517800467, ''),
#   Text(1.070141999232268, -0.25455078369387185, ''),
#   Text(1.072343601807133, -0.2451105865998144, ''),
#   Text(1.0744619299221578, -0.23565135507344834, ''),
#   Text(1.0754898143974037, -0.23091483089537213, ''),
#   Text(1.0764968190753774, -0.2261738236856654, ''),
#   Text(1.0784481112444055, -0.21667872842846067, ''),
#   Text(1.0803156548987056, -0.20716680665777806, ''),
#   ...])

# %%
sns.lineplot(x=a,y=b,data=df)
# Out:
# <Axes: xlabel='chol', ylabel='thal'>

# %%
sns.scatterplot(x=a,y=b,data=df)
# Out:
# <Axes: xlabel='chol', ylabel='thal'>

# %%
sns.barplot(x=a,y=c,data=df)
# Out:
# <Axes: xlabel='chol', ylabel='sex'>

# %%
sns.displot(a)

# %%
sns.pairplot(data=df,hue='target')

# %%
sns.countplot(x=a,data=df)
# Out:
# <Axes: xlabel='chol', ylabel='count'>

# %%
X=df.drop('target',axis=1)
Y=df['target']
X
Y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1020    1
# 1021    0
# 1022    0
# 1023    1
# 1024    0
# Name: target, Length: 1025, dtype: int64

# %%
#Train and Test
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.20,random_state=0)
x_train
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 315    42    1   3       148   244    0        0      178      0      0.8
# 204    66    0   2       146   278    0        0      152      0      0.0
# 363    53    1   2       130   246    1        0      173      0      0.0
# 5      58    0   0       100   248    0        0      122      0      1.0
# 1017   53    1   0       123   282    0        1       95      1      2.0
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 835    49    1   2       118   149    0        0      126      0      0.8
# 192    67    0   2       115   564    0        0      160      0      1.6
# 629    65    1   3       138   282    1        0      174      0      1.4
# 559    67    1   0       120   237    0        1       71      0      1.0
# 684    60    1   2       140   185    0        0      155      0      3.0
#
#       slope  ca  thal
# 315       2   2     2
# 204       1   1     2
# 363       2   3     2
# 5         1   0     2
# 1017      1   2     3
# ...     ...  ..   ...
# 835       2   3     2
# 192       1   0     3
# 629       1   1     2
# 559       1   0     2
# 684       1   0     2
#
# [820 rows x 13 columns]

# %%
#Standardization
from sklearn.preprocessing import StandardScaler
a=StandardScaler()
x_train=a.fit_transform(x_train)
x_train
# Out:
# array([[-1.40503359,  0.64895597,  1.97748631, ...,  0.97028605,
#          1.17427458, -0.5144228 ],
#        [ 1.26270023, -1.5409366 ,  1.01170979, ..., -0.6668221 ,
#          0.21616   , -0.5144228 ],
#        [-0.18232226,  0.64895597,  1.01170979, ...,  0.97028605,
#          2.13238916, -0.5144228 ],
#        ...,
#        [ 1.15154465,  0.64895597,  1.97748631, ..., -0.6668221 ,
#          0.21616   , -0.5144228 ],
#        [ 1.3738558 ,  0.64895597, -0.91984324, ..., -0.6668221 ,
#         -0.74195458, -0.5144228 ],
#        [ 0.59576677,  0.64895597,  1.01170979, ..., -0.6668221 ,
#         -0.74195458, -0.5144228 ]])

# %%
from sklearn.preprocessing import LabelEncoder
f=LabelEncoder()
f
# Out:
# LabelEncoder()

# %%
from sklearn.tree import DecisionTreeClassifier
clf=DecisionTreeClassifier()
clf.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred=clf.predict(x_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(

# %%
from sklearn.metrics import accuracy_score,confusion_matrix
accuracy_score(y_pred,y_test)
# Out:
# 0.47804878048780486

# %%
confusion_matrix(y_pred,y_test)
# Out:
# array([[ 98, 107],
#        [  0,   0]])
